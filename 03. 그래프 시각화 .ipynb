# %% [markdown]
# # Graph Visualization

# %% [markdown]
# ---
# ## Load Packages

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline #내부에다가 시각화를 하겠다는 뜻입니다.
# Out:
# UsageError: unrecognized arguments: #내부에다가 시각화를 하겠다는 뜻입니다.

# %% [markdown]
# ---
# ## Basic Attributes
#
# alpha : 투명도
# kind : 그래프 종류 'line', 'bar', 'barh', 'kde'
# logy : Y축에 대해 Log scaling
# use_index : 객체의 색인을 눈금 이름으로 사용할지 여부
# rot : 눈금 이름 돌리기 (rotating) 0 ~ 360
# xticks, yticks : x, y축으로 사용할 값
# xlim, ylim : X, Y축의 한계
# grid : 축의 그리드를 표현할지 여부
#
# subplots : 각 column에 독립된 subplot 그리기
# sharex, sharey : subplots=True 이면 같은 X,Y축을 공유하고 눈금과 한계를 연결
# figsize : 생성될 그래프의 크기를 tuple로 지정
# title : 그래프의 제목 지정
# legend : subplot의 범례 지정
# sort_columns : column을 알파벳 순서로 그린다.

# %% [markdown]
# ---
# # Matplotlib 사용하기

# %% [markdown]
# ---
# ## 점선 그래프 그리기

# %%
data=np.random.randn(50).cumsum()
data
# Out:
# array([-0.93189149, -1.32603587, -3.65464355, -3.62688974, -2.61522641,
#        -1.54763938, -1.26051615,  0.22939665,  0.43876415, -0.12601357,
#        -0.55086907, -0.10065726, -0.18467952, -1.23914125, -0.88069611,
#        -2.55835148, -3.30536835, -4.45914615, -4.36310201, -4.78087779,
#        -2.97126182, -4.07846086, -3.6089601 , -3.57559802, -2.31531187,
#        -2.88841176, -3.96115539, -1.17765104, -0.09692358, -1.82681096,
#        -2.5752864 , -3.17779051, -2.49220646, -2.37559159, -2.57176444,
#        -2.88415577, -2.02360353, -3.09668331, -4.14882418, -3.8096277 ,
#        -2.29809993, -2.15520894, -1.37756129, -1.15214326, -1.70304108,
#        -1.47506075, -1.68038162, -2.10686189, -0.49181272, -1.36515242])

# %%
plt.plot(data)

# %%
plt.plot(np.random.randn(50).cumsum(), 'k--')  # cumsum은 random하게 생성된 값들의 누적

plt.show()

# %% [markdown]
# ## 여러 그래프 그릴 준비 하기

# %%
plt.subplot(1, 2, 1)
plt.subplot(122)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Multi Graph 그리기

# %%
plt.subplot(2, 2, 1)
plt.plot(np.random.randn(100).cumsum(), 'k--')
plt.subplot(2, 2, 2)
plt.hist(np.random.randn(100), bins=100, color='k', alpha=0.3)
plt.subplot(2, 2, 3)
plt.scatter(np.arange(30), np.random.randn(30))
plt.show()

# %% [markdown]
# ---
# ## 그래프 선 옵션

# %% [markdown]
# - 그래프를 그릴 때 표시 되는 색이나 마커 패턴을 바꾸는 것 확인
#     - 색상: b(파란색), g(초록색), r(빨간색), c(청록색), y(노란색), k(검은색), w(흰색)
#     - 마커: o(원), v(역삼각형), ^(삼각형), s(네모), +(플러스), .(점)

# %%
x = np.arange(30)
y = np.arange(30) + 3 * np.random.randn(30)

# %%
plt.plot(x, y, 'g--')
plt.show()

# %%
plt.plot(x, y, 'g+')
plt.show()

# %%
plt.plot(x, y, 'b.')
plt.show()

# %%
# 검은색은 k
plt.plot(x, y, 'k.')
plt.show()

# %% [markdown]
# # 그래프 사이즈 조절

# %% [markdown]
# - plt.figure 안에 figsize를 이용하여 가로, 세로 길이 조절 가능 (inch 단위)

# %%
plt.figure(figsize=(10, 10))
plt.plot(x, y, 'k.')
plt.show()

# %% [markdown]
# - 여러 그래프 그리고 그에 대한 크기 조절

# %%
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.plot(x, y, 'g--')
plt.subplot(2, 2, 2)
plt.plot(x, y, 'k.')
plt.subplot(2, 2, 3)
plt.plot(x, y, 'b.')
plt.show()

# %% [markdown]
# - 비율 조절

# %%
plt.figure(figsize=(20, 10))
plt.subplot(2, 2, 1)
plt.plot(x, y, 'g--')
plt.subplot(2, 2, 2)
plt.plot(x, y, 'k.')
plt.subplot(2, 2, 3)
plt.plot(x, y, 'b.')
plt.show()

# %% [markdown]
# ---
# ## 그래프 겹치기 + legend 달기

# %%
data = np.random.randn(30).cumsum()

plt.plot(data, 'k--', label='Default')
plt.plot(data, 'k-', drawstyle='steps-post', 
         label='steps-post')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ---
# ## 이름 달기

# %%
plt.plot(np.random.randn(1000).cumsum())
plt.title('Matplotlib Plot')
plt.xlabel('Stages')
plt.show()

# %% [markdown]
# ---
# ## 종합

# %%
plt.plot(np.random.randn(1000).cumsum(), 
        'k', label='one')
plt.plot(np.random.randn(1000).cumsum(), 
        'k--', label='two')
plt.plot(np.random.randn(1000).cumsum(), 
        'k.', label='three')

plt.legend(loc='best')
plt.show()

# %% [markdown]
# ---
# ## 그래프 저장하기

# %%
plt.savefig("fig_saved.svg")
